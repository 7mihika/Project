# %% [markdown]
# 1. Variables and Data type

# %%
name = "Khushi"
age = 20
height = 5
is_student = True

# %%
print(name, age, height, is_student)
# Out:
# Khushi 20 5 True

# %%
type(name)
# Out:
# str

# %%
name=str(name)

# %% [markdown]
# 2. Input and Output

# %%
print("hello", "world", "from", "python")
# Out:
# hello world from python

# %%
name = input("give me your name:")
print(f"hello {name}")
# Out:
# give me your name: khushi
# hello khushi

# %%
a = int(input("enter a number:"))
print(a*2)
# Out:
# enter a number: 60

# %%
name = "khushi singh"
marks = 85

# %%
print(f"{name} has scored {marks} out of 100")
# Out:
# khushi singh has scored 85 out of 100

# %%
print(f"Percentage : {marks:1f}%")
# Out:
# Percentage : 85.000000%

# %% [markdown]
# 3. Operators

# %%
a, b =10,3
print(a+b, a-b, a*b)
# Out:
# 13 7 30

# %%
a,b = 10,3
print(a / b)  # division
print(a // b) # floor  division
print(a % b) # remainder and modula operater
print(a ** b) # exponent
# Out:
# 3.3333333333333335
# 3
# 1
# 1000

# %% [markdown]
# 4. Arithmetic Eg

# %%
price = 250
quantity = 4
tax = 0.18
total = price*quantity*(1+tax)
print(total)
# Out:
# 1180.0

# %% [markdown]
# 5. Comparision

# %%
print(10 > 5)
print(10 == 5)
print(10 != 5)
# Out:
# True
# False
# True

# %%
marks = 75
print(50 <= marks <= 100)
# Out:
# True

# %% [markdown]
# 6. Logical

# %%
x,y = True ,False
print(x and y)
print(x or y)
print(not x)
# Out:
# False
# True
# False

# %%
age = 22
has_id = True
print(age >= 18 and has_id)
# Out:
# True

# %%
income = 50000
credit_score = 720

# %%
eligible = income >30000 and credit_score >350
print(eligible)
# Out:
# True

# %% [markdown]
# 7. List

# %%
numbers = [10,20,30,40]
print(numbers)
# Out:
# [10, 20, 30, 40]

# %%
print(numbers[0])
# Out:
# 10

# %%
print(numbers[0:40])
# Out:
# [10, 20, 30, 40]

# %%
print(numbers[1:4])
# Out:
# [20, 30, 40]

# %% [markdown]
# 8. Modify, Append, Remove list

# %%
fruits =["apple", "banana", "mango"]

# %%
print(fruits[2])
# Out:
# mango

# %%
fruits.append("orange")

# %%
print(fruits)
# Out:
# ['apple', 'banana', 'mango', 'orange']

# %%
nums = [1, 4, 5, 6, 8]
print(len(nums)) 
print(sum(nums))
print(max(nums), min(nums))
# Out:
# 5
# 24
# 8 1

# %%
nums =[2, 10, 5, 4, 1, 3] 
nums.sort()

# %%
print(nums)
# Out:
# [1, 2, 3, 4, 5, 10]

# %%
nums = [10,20,30,40,50]
print(nums[1:4])
# Out:
# [20, 30, 40]

# %%
print(nums[:3])
# Out:
# [10, 20, 30]

# %%
print(nums[::])
# Out:
# [10, 20, 30, 40, 50]

# %%
print(nums[::-1])
# Out:
# [50, 40, 30, 20, 10]

# %%
print(nums[-3])
# Out:
# 30

# %%
print(nums[-3:])
# Out:
# [30, 40, 50]

# %%
print(nums[1:5:2])
# Out:
# [20, 40]

# %% [markdown]
# 9. Loops

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(2,11,2):
    print(i)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
marks = [70, 80, 90]
for mark in marks:
    print(mark)
# Out:
# 70
# 80
# 90

# %%
# while loop

# %%
count = 1 
while count <= 5:  
    print(count)  
    count +=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
n = 0
while True:
    if n == 3:
        break
        print("n = ", n) 
        n += 1

# %% [markdown]
# 10. Conditional statement

# %%
age = 22 
if age >= 18
    print("adult")

# %%
age = 15
if age >= 18:
    print("adult")
else:
    print("minor")

# %%
marks  int(input("enter your marks here :")) 
if marks >= 90:
    print("A")
elif marks >=80:
    print("B")
elif marks >=70:
    print("C")
else:
    print("Fail")
